# %% [markdown]
# # TfNSW Data Exploration
#
# ## Objective
#
# Explore TfNSW Sydney Trains data in Python, similar to the analysis in R.

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import altair as alt
#import plotly.express as px
#import plotly.io as pio
#import plotly.graph_objects as go

#pio.templates.default = 'plotly_dark'

# %% [markdown]
# ## Import data

# %%
routes = pd.read_csv("data/routes.csv") \
    .query('agency_id == "SydneyTrains"') \
    .drop(['agency_id', 'route_type', 'route_url', 'route_text_color'], axis = 1) \
    .dropna()

routes.head(5)
# Out:
#   route_id route_short_name                         route_long_name  \
# 0   APS_1a               T8    City Circle to Macarthur via Airport
# 1   APS_1b               T8   City Circle to Leppington via Airport
# 2   APS_1c               T8   City Circle to Macarthur via Sydenham
# 3   APS_1d               T8   City Circle to Macarthur via Sydenham
# 4   APS_1e               T8  City Circle to Leppington via Sydenham
#
#                 route_desc route_color
# 0  T8 Airport & South Line      00954C
# 1  T8 Airport & South Line      00954C
# 2  T8 Airport & South Line      00954C
# 3  T8 Airport & South Line      00954C
# 4  T8 Airport & South Line      00954C

# %%
stops = pd.read_csv("data/stops.csv") \
    .drop(['stop_timezone', 'wheelchair_boarding', 'stop_desc', 'zone_id', 'stop_url'], axis = 1)
stops.head(5)
# Out:
#   stop_id stop_code                    stop_name   stop_lat    stop_lon  \
# 0   26401     26401               Albury Station -36.084068  146.924691
# 1  264086    264086    Albury Station Platform 1 -36.083941  146.924558
# 2  233610    233610             Aberdeen Station -32.167104  150.892052
# 3  233621    233621  Aberdeen Station Platform 1 -32.166969  150.892016
# 4  222020    222020              Allawah Station -33.969584  151.114330
#
#    location_type parent_station
# 0              1            NaN
# 1              0          26401
# 2              1            NaN
# 3              0         233610
# 4              1            NaN

# %%
trips = pd.read_csv("data/trips.csv") \
    .drop(['service_id', 'trip_short_name', 'block_id', 'wheelchair_accessible'], axis = 1)
trips.head(10)
# Out:
#    route_id                         trip_id              trip_headsign  \
# 0  RTTA_REV  1--A.1259.126.128.B.8.59842229                Empty Train
# 1  RTTA_REV    1--A.1259.126.2.B.8.59842229                Empty Train
# 2    BNK_2a  1--A.1260.127.124.B.8.59851802     City Circle via Museum
# 3    BNK_2a  1--A.1495.102.124.B.8.59416274     City Circle via Museum
# 4  RTTA_REV  1--A.1495.102.130.B.8.59416276                Empty Train
# 5  RTTA_REV  1--A.1620.103.134.B.8.59625698                Empty Train
# 6    BNK_2a    1--A.483.104.56.B.8.59918823     City Circle via Museum
# 7    BNK_2a    1--A.483.104.64.B.8.59918823     City Circle via Museum
# 8    BNK_2d  1--B.1259.126.128.B.8.59842228  City Circle via Town Hall
# 9    BNK_2d    1--B.1259.126.2.B.8.59842228  City Circle via Town Hall
#
#    direction_id  shape_id
# 0             0  RTTA_REV
# 1             0  RTTA_REV
# 2             1    BNK_2a
# 3             1    BNK_2a
# 4             0  RTTA_REV
# 5             0  RTTA_REV
# 6             1    BNK_2a
# 7             1    BNK_2a
# 8             1    BNK_2d
# 9             1    BNK_2d

# %%
stop_times = pd.read_csv("data/stop_times.csv", low_memory = False) \
    .drop(['arrival_time', 'departure_time', 'stop_headsign', 'pickup_type', 'drop_off_type', "shape_dist_traveled"], axis = 1)

stop_times.head(5)
# Out:
#                           trip_id  stop_id  stop_sequence
# 0  1--A.1259.126.128.B.8.59842229  2142324              8
# 1  1--A.1259.126.128.B.8.59842229  2160262             13
# 2  1--A.1259.126.128.B.8.59842229  2161252             14
# 3  1--A.1259.126.128.B.8.59842229  2161262             17
# 4  1--A.1259.126.128.B.8.59842229  2165202             19

# %%
stop_seq = pd.merge(stop_times, stops, on = 'stop_id')
stop_seq = pd.merge(stop_seq, trips, on = 'trip_id') \
    .drop(['stop_lat', 'stop_lon', 'stop_code'], axis = 1)

stop_seq.head(5)
# Out:
#                           trip_id  stop_id  stop_sequence  \
# 0  1--A.1259.126.128.B.8.59842229  2142324              8
# 1  1--A.1259.126.128.B.8.59842229  2160262             13
# 2  1--A.1259.126.128.B.8.59842229  2161252             14
# 3  1--A.1259.126.128.B.8.59842229  2161262             17
# 4  1--A.1259.126.128.B.8.59842229  2165202             19
#
#                        stop_name  location_type parent_station  route_id  \
# 0   Granville Station Platform 4              0         214240  RTTA_REV
# 1  Merrylands Station Platform 2              0         216010  RTTA_REV
# 2   Guildford Station Platform 2              0         216110  RTTA_REV
# 3     Yennora Station Platform 2              0         216120  RTTA_REV
# 4   Fairfield Station Platform 2              0         216510  RTTA_REV
#
#   trip_headsign  direction_id  shape_id
# 0   Empty Train             0  RTTA_REV
# 1   Empty Train             0  RTTA_REV
# 2   Empty Train             0  RTTA_REV
# 3   Empty Train             0  RTTA_REV
# 4   Empty Train             0  RTTA_REV

# %%
# shapes = pd.read_csv("data/shapes.csv")
# shapes.head(5)

# %% [markdown]
# ## Distinct trips

# %%
trips_per_route = pd.merge(trips, routes, on = 'route_id') \
    .groupby(by = ['route_long_name', 'route_color']) \
    .count() \
    .filter(items=['trip_id']) \
    .sort_values('trip_id', ascending = False)

# %%
len(trips_per_route)
# Out:
# 49

# %%
trips_per_route.head(5)
# Out:
#                                                          trip_id
# route_long_name                             route_color
# City to Berowra via Gordon                  F99D1C          3474
# North Shore to Hornsby and Berowra via City D11F2F          2770
# Berowra and Hornsby to City via Gordon      F99D1C          2381
# City Circle to Macarthur via Airport        00954C          2086
# Macarthur to City Circle via Airport        00954C          1934

# %%
route_colours = pd.DataFrame(data = np.array(routes.route_color.drop_duplicates().map(lambda x: "#" + x)),
                             columns = ['rgb'],
                             index = routes.route_color.drop_duplicates())
route_colours
# Out:
#                  rgb
# route_color
# 00954C       #00954C
# F37021       #F37021
# C4258F       #C4258F
# 005AA3       #005AA3
# 0098CD       #0098CD
# F99D1C       #F99D1C
# D11F2F       #D11F2F
# 6F818E       #6F818E

# %%
alt.Chart(trips_per_route.reset_index()) \
    .mark_bar(
        tooltip = True) \
    .encode(
        x = alt.X(
            'trip_id', 
            title = 'Number of trips'),
        y = alt.Y(
            'route_long_name', 
            sort = '-x', 
            title = None),
        color = alt.Color(
            'route_color', 
            scale = alt.Scale(
                domain = route_colours.index.to_list(), 
                range = route_colours['rgb'].to_list()),
            legend = None)) \
    .properties(
        width = 800,
        height = 600,
        title = 'Trips per route') \
    .configure_title(
        fontSize = 20,
        color = '#666666',
        dy = -20,
        anchor = 'start')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Stops per trip

# %%
def stops_by_trip_id (id):
    
    x = stop_seq[stop_seq.trip_id == id].drop_duplicates()
    return pd.merge(x, stops, on = 'stop_id') \
        .filter(['stop_name_x'], axis=1)


def stops_by_route_id (id):
    
    x = trips[trips.route_id == id] \
        .head(1) \
        .trip_id \
        .item()
    return stops_by_trip_id(x)

# %%
stops_by_route_id('CCN_1a')
# Out:
#                                  stop_name_x
# 0                 Redfern Station Platform 6
# 1           Macdonaldtown Station Platform 2
# 2                 Newtown Station Platform 2
# 3                Stanmore Station Platform 3
# 4               Petersham Station Platform 2
# 5                Lewisham Station Platform 2
# 6             Summer Hill Station Platform 3
# 7                Ashfield Station Platform 5
# 8                 Croydon Station Platform 5
# 9                 Burwood Station Platform 6
# 10            Strathfield Station Platform 6
# 11             Meadowbank Station Platform 2
# 12              West Ryde Station Platform 3
# 13             Cheltenham Station Platform 2
# 14               Beecroft Station Platform 2
# 15          Pennant Hills Station Platform 2
# 16             Thornleigh Station Platform 3
# 17            Normanhurst Station Platform 2
# 18                Asquith Station Platform 2
# 19            Mount Colah Station Platform 2
# 20       Mount Kuring-gai Station Platform 2
# 21                Berowra Station Platform 2
# 22      North Strathfield Station Platform 2
# 23           Concord West Station Platform 3
# 24                 Rhodes Station Platform 2
# 25               Central Station Platform 11
# 26              Denistone Station Platform 4
# 27               Eastwood Station Platform 4
# 28                 Epping Station Platform 3
# 29                Hornsby Station Platform 5
# 30  Newcastle Interchange Station Platform 2
# 31                  Cowan Station Platform 2
# 32       Hawkesbury River Station Platform 2
# 33              Wondabyne Station Platform 2
# 34                Woy Woy Station Platform 2
# 35              Koolewong Station Platform 2
# 36                Tascott Station Platform 2
# 37            Point Clare Station Platform 2
# 38                Gosford Station Platform 2
# 39                 Narara Station Platform 2
# 40           Niagara Park Station Platform 2
# 41                Lisarow Station Platform 2
# 42               Ourimbah Station Platform 2
# 43               Tuggerah Station Platform 2
# 44                  Wyong Station Platform 3
# 45             Warnervale Station Platform 2
# 46                   Wyee Station Platform 2
# 47               Morisset Station Platform 2
# 48             Dora Creek Station Platform 2
# 49                  Awaba Station Platform 2
# 50              Fassifern Station Platform 2
# 51               Booragul Station Platform 2
# 52                Teralba Station Platform 2
# 53           Cockle Creek Station Platform 2
# 54                Cardiff Station Platform 2
# 55                 Kotara Station Platform 2
# 56              Adamstown Station Platform 2
# 57            Broadmeadow Station Platform 2
# 58               Hamilton Station Platform 2

# %%
stops_by_trip_id('N135.1495.102.44.V.8.59426689')
# Out:
#                                  stop_name_x
# 0              Meadowbank Station Platform 2
# 1               West Ryde Station Platform 3
# 2              Cheltenham Station Platform 2
# 3                Beecroft Station Platform 2
# 4           Pennant Hills Station Platform 2
# 5              Thornleigh Station Platform 3
# 6             Normanhurst Station Platform 2
# 7                 Asquith Station Platform 2
# 8             Mount Colah Station Platform 2
# 9        Mount Kuring-gai Station Platform 2
# 10      North Strathfield Station Platform 2
# 11           Concord West Station Platform 3
# 12                 Rhodes Station Platform 2
# 13                Redfern Station Platform 2
# 14                Croydon Station Platform 1
# 15                Burwood Station Platform 2
# 16            Strathfield Station Platform 3
# 17              Denistone Station Platform 4
# 18               Eastwood Station Platform 4
# 19                 Epping Station Platform 3
# 20                Hornsby Station Platform 5
# 21                Berowra Station Platform 3
# 22                  Cowan Station Platform 2
# 23       Hawkesbury River Station Platform 2
# 24              Wondabyne Station Platform 2
# 25                Woy Woy Station Platform 2
# 26              Koolewong Station Platform 2
# 27                Tascott Station Platform 2
# 28            Point Clare Station Platform 2
# 29                Gosford Station Platform 2
# 30                 Narara Station Platform 2
# 31           Niagara Park Station Platform 2
# 32                Lisarow Station Platform 2
# 33               Ourimbah Station Platform 2
# 34               Tuggerah Station Platform 2
# 35                  Wyong Station Platform 3
# 36             Warnervale Station Platform 2
# 37                   Wyee Station Platform 2
# 38               Morisset Station Platform 2
# 39             Dora Creek Station Platform 2
# 40                  Awaba Station Platform 2
# 41              Fassifern Station Platform 2
# 42               Booragul Station Platform 2
# 43                Teralba Station Platform 2
# 44           Cockle Creek Station Platform 2
# 45                Cardiff Station Platform 2
# 46                 Kotara Station Platform 2
# 47              Adamstown Station Platform 2
# 48            Broadmeadow Station Platform 2
# 49               Hamilton Station Platform 2
# 50  Newcastle Interchange Station Platform 3
# 51               Central Station Platform 10

# %%
trips[trips.route_id == 'CCN_1a'].head(1).trip_id.item()
# Out:
# '202B.1260.127.16.H.4.60059035'

# %%
stop_seq.tail(5)
# Out:
#                              trip_id stop_id  stop_sequence  \
# 957332  SP43.483.104.16.P.2.59916941  266348              1
# 957333  SP43.483.104.16.P.2.59916941  268058             10
# 957334  SP43.483.104.16.P.2.59916941   27054              8
# 957335  SP43.483.104.16.P.2.59916941   27003              7
# 957336  SP43.483.104.16.P.2.59916941  270122              6
#
#                             stop_name  location_type parent_station route_id  \
# 957332       Junee Station Platform 3              0          26631  CTY_S1f
# 957333    Griffith Station Platform 1              0          26801  CTY_S1f
# 957334      Leeton Station Platform 1              0          27051  CTY_S1f
# 957335  Narrandera Station Platform 1              0          27001  CTY_S1f
# 957336    Coolamon Station Platform 1              0          27011  CTY_S1f
#
#        trip_headsign  direction_id shape_id
# 957332      Griffith             0  CTY_S1f
# 957333      Griffith             0  CTY_S1f
# 957334      Griffith             0  CTY_S1f
# 957335      Griffith             0  CTY_S1f
# 957336      Griffith             0  CTY_S1f
